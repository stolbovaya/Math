# %% [markdown]
# # 1. Задание

# %%
import numpy
input_arr1 = numpy.array([[ 5, 10 ],[ 7, 12],[11.3,5],[25,30]]) 
input_arr2 = numpy.array([[ 5, 10 ],[ 7, 12],[11.3,5],[25,30]]) 
print(input_arr1)
print(input_arr2)
# Out:
# [[ 5.  10. ]
#  [ 7.  12. ]
#  [11.3  5. ]
#  [25.  30. ]]
# [[ 5.  10. ]
#  [ 7.  12. ]
#  [11.3  5. ]
#  [25.  30. ]]

# %%
out_arr=7*input_arr1+2*input_arr2
print(out_arr)
# Out:
# [[ 45.   90. ]
#  [ 63.  108. ]
#  [101.7  45. ]
#  [225.  270. ]]

# %% [markdown]
# # 4. Задание

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0, 50, 50)
k1=1
k2=3
plt.plot(x, np.cos(k1*x))
plt.plot(x, np.cos(k2*x))
